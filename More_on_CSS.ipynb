# %% [markdown]
# 1.  Create a navigation bar similar to the below-mentioned image. The navigation bar must contain 5
# navigation links that are properly placed within the navigation bar using the CSS box model. The navigation
# items must change their text color on hover.

# %%
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title> Navigation Bar </title>

    <style>

       body{

       margin: 20px;
       }

       .nav {

        background-color: #85abf1;
        text-align: left;
        padding: 10px;
        word-spacing: 10px;

       }

    .nav a {

        color: white;
        display: inline-block;
        padding: 10px 15px;

    }

    .nav a:hover {

        color: rgb(37, 9, 114); /* Change the colour on hover */
    }


    </style>
</head>
<body>

    <div class="nav">
        <a href="#"> Home</a>
        <a href="#"> About Us</a>
        <a href="#"> Contact</a>
        <a href="#"> Blog</a>
        <a href="#"> Login</a>
    </div>

</body>
</html>

# %% [markdown]
#  2. Create a div centered with an image and paragraph similar to the image mentioned below.

# %%
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title> An image and paragraph</title>

    <style>


        body {


            align-items:  center;
            justify-content: center;
            display:flex;
            height: 100vh;
            padding: 0;
            margin: 0;

                                                                                       ;
        }

        .card img {

            height: auto;
            width: 100%;
        }

        .card p {

            padding: 2px 10px 10px 10px;
            font-weight: bold;
        }

        .card {

            border-radius: 15px;
            width: 300px;
            text-align: center;
            width: 300px;
            box-shadow: 0 4px 8px rgba(0, 0, 0, 0.2);
            background-color: yellow;
        }

    </style>
</head>
<body>

    <div class="card">

        <p>
            <img src="media/image.png" alt="cousre image">

            <br>
           <b> Course Name:</b> PW Skills full stack web development
        </p>

    </div>

</body>
</html>

# %% [markdown]
# 3.  Create a navigation bar similar to question 1. For each navigation item, use a different border style.

# %%
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title> Navigation Bar </title>

    <style>

       body{

       margin: 20px;
       }

       .nav {

        background-color: #85abf1;
        text-align: left;
        padding: 10px;
        word-spacing: 10px;

       }

    .nav a {

        color: white;
        display: inline-block;
        padding: 10px 15px;

    }

    .nav a:hover {

        color: rgb(37, 9, 114); /* Change the colour on hover */
    }

    .nav_home {

        border: 3px solid white;
    }

    .nav_aboutus {

        border: 3px dashed rgb(235, 230, 230);
    }

    .nav_contact {

        border: 3px dotted rgb(208, 239, 241);
    }

    .nav_blog {

        border: 3px double rgb(241, 220, 241);
    }

    .nav_login {

        border: 3px groove white;
    }
    </style>
</head>
<body>

    <div class="nav">
        <a href="#" class="nav_home"> Home</a>
        <a href="#" class="nav_aboutus"> About Us</a>
        <a href="#" class="nav_contact"> Contact</a>
        <a href="#" class="nav_blog"> Blog</a>
        <a href="#" class="nav_login"> Login</a>
    </div>

</body>
</html>

# %% [markdown]
# 4. Create a simple webpage with an image and make the image circular using border-radius.

# %%
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Circular image</title>

    <style>


        img {

            border-radius: 90%;
            width: 250px;
            height: 250px;
            object-fit: cover;

        }
    </style>
</head>

<body>

     <img src="media/image2.png" alt="Circular image">


</body>
</html>

# %% [markdown]
# 5. Create a simple blog website about Google fonts. The webpage must have the heading with “Oswald” font
# align center to the page, below the heading have an image of Google fonts and a paragraph about Google
# fonts in font “Montserrat” paragraph font style should be “montserrat” font.

# %%
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title> About Google Fonts </title>


    <Style>



        body {

            text-align: center;
            margin: 30px;


        }
        h1 {

           @import url(https://fonts.googleapis.com/css?family=Oswald:200,300,regular,500,600,700);
            font-family: oswald ;
            font-size: 70px;
            margin-bottom: 20px;

        }

        img {
            max-width: 50%;
            height: auto;
            margin-bottom: 20px;

        }

        p {

            @import url(https://fonts.googleapis.com/css?family=Montserrat:100,200,300,regular,500,600,700,800,900,100italic,200italic,300italic,italic,500italic,600italic,700italic,800italic,900italic);
            font-family: montserrat;
            max-width: 800px;
            margin: auto;
            text-align: justify;
        }
    </Style>
</head>
<body>

    <h1> Google Fonts </h1>

    <img src="media/Googlefont.png" alt="Google_Fonts_logo">

    <p>
        Our font catalog places typography front and center,
        inviting users to explore, sort, and test fonts for
        use in more than 135 languages. We showcase individual
        type designers and foundries, giving you valuable
        information about the typographers and their process,
        as well as analytics on usage and demographics.
        Our default sort organizes fonts based on popularity,
        trends, and your geographic location. You can also
        create your own selections by filtering families,
        weights, and writing systems, plus test color
        themes, and review custom sample texts.
    </p>
</body>
</html>

# %% [markdown]
# 6. Create a simple website as mentioned in the below image. You can get the assets by visiting https://
#  pwskills.com/about-us.

# %%
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title> PW Skills About Us</title>

    <style>


        body {

            margin: 0;
            padding: 0;
            border: 2px solid black;
            font-family: arial, sans-serif;

        }

        .container {

            max-width: 1000%;
            margin: auto;
            padding: 20px;
        }
        h1{

            text-align: center;
            font-family: sans-serif;
            margin-bottom: 40px;
            margin-top: 5px;
        }

        img {

            max-width: 100%;


        }

        .img-container {

            justify-content: center;
            margin-top: 30px;
        }

        p {
            line-height: 1.5;
            text-align: left;
            font-size: small;

        }

    </style>
</head>
<body>

    <div class="container">

        <h1>
        About Us
    </h1>

    <p>
        PW Skills' mission is to permeate through every
        student/professional's outlook towards jobs and
        change their attitude and perspective from "How
        Can I Do It?" to "Of Course I Can Do It". We aim
        to do this by providing exceptional up skilling
        courses at affordable rates, while being tech-
        forward so anyone, anywhere can access and
        improve their ability to be successful in life.
    </p>

    <div class="img-container">
         <img src="media/PWaboutUs.png" alt="PW aboutUs">
    </div>
    </div>

</body>
</html>

# %% [markdown]
# 7.  Create a simple webpage with a card similar to question number 2. The card must be semi-transparent as
# default and on hovering the card must be displayed clearly. Use CSS opacity to achieve this output.

# %%
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title> Hover Card</title>

    <style>


        body {

            border: 2px solid black;
            align-items:  center;
            justify-content: center;
            display:flex;
            min-height: 100vh;
            padding: 0;
            margin: 30%;

                                                                          ;
        }

        .card img {

            height: auto;
            width: 100%;
        }

        .card p {

            padding: 5px;
            font-weight: bold;
        }

        .card {

            border-radius: 15px;
            width: 300px;
            text-align: center;
            width: 300px;
            background-color: rgb(79, 219, 219);
            opacity: 0.5;

        }

        div {

            margin: 2px;
        }

        .card:hover {

          opacity: 1;
        }
    </style>
</head>
<body>

    <div class="card">

        <p>
            <img src="media/image.png" alt="cousre image">

            <br>
           <b> Course Name:</b> PW Skills full stack web development
        </p>

    </div>

</body>
</html>

# %% [markdown]
# 8. Create a simple list of items as mentioned in the below image.

# %%
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title> List of items </title>

    <style>

        div {

            border: 2px solid black;
            width: 400px;
            font-size: large;
            padding: 10px;
        }

    </style>
</head>
<body>

    <div>

        <h1> Requirements</h1>

        <ol type="i">

            <li> System with minimum i3 processor or better.</li>
            <li> At least 4 GB of RAM. </li>
            <li> Working internet connection. </li>
            <li> Dedication to learn </li>
        </ol>

    </div>
</body>
</html>
